# %% [markdown]
# ### Import MySQL Libraries

# %%
import pandas as pd
import numpy as np
import mysql.connector
from mysql.connector import Error
import datetime as dt

# %%
# %store -r HOST
# %store -r USER
# %store -r PASS

# %%
host=HOST
user = USER
password = PASS

# %% [markdown]
# ### Connecting to MySQL Server

# %%
def create_server_connection(host_name, user_name, user_password):
    connection = None
    try:
        connection = mysql.connector.connect(
        host=host_name,
        user=user_name,
        passwd=user_password
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    return connection

# %% [markdown]
# ### Creating a New Databse

# %%
def create_database(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        print("Database created successfully")
    except Error as err:
        print(f"Error: '{err}'")

# %% [markdown]
# ### Connecting to the Database

# %%
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = mysql.connector.connect(
        host=host_name,
        user=user_name,
        passwd=user_password,
        database=db_name
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")
    return connection

# %% [markdown]
# ### Creating a Query Execution Function

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query successful")
    except Error as err:
        print(f"Error: '{err}'")

# %% [markdown]
# ### Reading Data

# %%
def read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as err:
        print(f"Error: '{err}'")

# %% [markdown]
# ### Creating Records from Lists

# %%
def execute_list_query(connection, sql, val):
    cursor = connection.cursor()
    try:
        cursor.executemany(sql, val)
        connection.commit()
        print("Query successful")
    except Error as err:
        print(f"Error: '{err}'")

# %%
connection = create_server_connection(host, user, password)
create_database(connection, "CREATE DATABASE IF NOT EXISTS music;")

connection.close()
# Out:
# MySQL Database connection successful
# Database created successfully

# %% [markdown]
# ### Creating the Channel Table

# %%
connection = create_db_connection(host,user,password,'music')
create_music_table = """ CREATE TABLE channels (
                            channel_id varchar(255) PRIMARY KEY,
                            channel_name varchar(255),
                            viewers bigint,
                            subscribers bigint,
                            published date); """
# Out:
# MySQL Database connection successful

# %%
execute_query(connection,create_music_table)
# Out:
# Error: '1050 (42S01): Table 'channels' already exists'

# %% [markdown]
# ### Creating the Video Table

# %%
create_vid_table = """ CREATE TABLE videos (
                            video_id varchar(255) PRIMARY KEY,
                            artist varchar(255),
                            title varchar(255),
                            likes bigint,
                            dislikes bigint,
                            views bigint,
                            comments bigint,
                            channel_id varchar(255),
                            FOREIGN KEY (channel_id) REFERENCES channels(channel_id)); """

# %%
execute_query(connection,create_vid_table)
# Out:
# Error: '1050 (42S01): Table 'videos' already exists'

# %%
channels = pd.read_csv("channels.csv",index_col=0)

# %%
channels.head()
# Out:
#                   channelId   channel_name      viewers  subscribers  \
# 0  UCTbOjJv4X1fk-LdfHnWAK1Q  Daniel Powter    243956424        32700
# 1  UCkdc7gHpavxpgGalxKbgSHA      Sean Paul   2157186944      3810000
# 2  UC5Y-gAeGpzgzu0ObzKnhPFA  Nelly Furtado   1849529691      1800000
# 3  UCUg8KhMXhFxJm-YQzOQ7nPw    James Blunt   1619839415      2700000
# 4  UCYLNGLIzMhRTi6ZOLjAPSmw        Shakira  21773623218     34400000
#
#               published  genre
# 0  2006-04-29T04:06:19Z    pop
# 1  2009-04-23T20:28:05Z    pop
# 2  2006-11-04T00:41:49Z  latin
# 3  2006-08-30T13:08:54Z    pop
# 4  2005-10-16T09:08:20Z    pop

# %% [markdown]
# ### Convert Published Date Column to a Date Type

# %%
channels['published']=pd.to_datetime(channels['published'])

# %%
channels['published']=pd.to_datetime(channels['published'],format="%Y-%m-%d")

# %%
channels['published']=channels['published'].dt.date

# %%
channels.head()
# Out:
#                   channelId   channel_name      viewers  subscribers  \
# 0  UCTbOjJv4X1fk-LdfHnWAK1Q  Daniel Powter    243956424        32700
# 1  UCkdc7gHpavxpgGalxKbgSHA      Sean Paul   2157186944      3810000
# 2  UC5Y-gAeGpzgzu0ObzKnhPFA  Nelly Furtado   1849529691      1800000
# 3  UCUg8KhMXhFxJm-YQzOQ7nPw    James Blunt   1619839415      2700000
# 4  UCYLNGLIzMhRTi6ZOLjAPSmw        Shakira  21773623218     34400000
#
#     published  genre
# 0  2006-04-29    pop
# 1  2009-04-23    pop
# 2  2006-11-04  latin
# 3  2006-08-30    pop
# 4  2005-10-16    pop

# %%
genres=pd.read_csv("genres.csv",index_col=0)

# %%
genres.head()
# Out:
#           artist            title  year  \
# 0  Daniel Powter          Bad Day  2006
# 1      Sean Paul      Temperature  2006
# 2  Nelly Furtado      Promiscuous  2006
# 3    James Blunt  Youre Beautiful  2006
# 4        Shakira    Hips Dont Lie  2006
#
#                                               lyrics  \
# 0  where is the moment we needed the most?you kic...
# 1  the gyal dem schillaci, sean a paulso me give ...
# 2  nelly furtado &timbalandam i throwin' you off?...
# 3  my life is brilliantmy life is brilliant, my l...
# 4  wyclef jeanladies up in here tonightno fightin...
#
#                                                words  genre
# 0  ['moment', 'needed', 'mostyou', 'kick', 'leaf'...    pop
# 1  ['gyal', 'dem', 'schillaci', 'sean', 'paulso',...    pop
# 2  ['nelly', 'furtado', 'timbalandam', 'throwin',...  latin
# 3  ['life', 'brilliantmy', 'brilliant', 'love', '...    pop
# 4  ['wyclef', 'jeanladies', 'tonightno', 'fightin...    pop

# %%
video = pd.read_csv("video.csv",index_col=0)

# %%
video
# Out:
#          video_id         artist  \
# 0     gH476CxJxfg  Daniel Powter
# 1     BbtcTb_WMsg  Daniel Powter
# 2     vEY_mg2y-rg  Daniel Powter
# 3     oDAqDLmixrw  Daniel Powter
# 4     5E4j_n17cTI  Daniel Powter
# ...           ...            ...
# 8939  m8rM7Tox1HE  Lewis Capaldi
# 8940  sB8n58FHBxw  Lewis Capaldi
# 8941  PUZqMw4rkVs  Lewis Capaldi
# 8942  oyBUgOFlBU4  Lewis Capaldi
# 8943  Q_uXabuUoFA  Lewis Capaldi
#
#                                                   title    likes  dislikes  \
# 0     Daniel Powter - Bad Day (Official Music Video)...  1534284     23998
# 1     Daniel Powter - Love You Lately (Official Musi...    20718       397
# 2      Daniel Powter - Free Loop (Official Music Video)    89155      1362
# 3       Save Your Life - Ayaka Hirahara & Daniel Powter     5164        50
# 4               Daniel Powter - Next Plane Home (Video)    13046       320
# ...                                                 ...      ...       ...
# 8939                              Lewis Capaldi - Grace   273709      5655
# 8940      Lewis Capaldi - Bruises (Official Live Video)   122915      2097
# 8941                 Lewis Capaldi - Lost On You (Live)   268949      3235
# 8942                        Lewis Capaldi - Fade (Live)    24233       243
# 8943  Lewis Capaldi - Hold Me While You Wait (Lyric ...    12419       351
#
#           views  comments             published
# 0     198275400     51550  2009-10-27T02:01:38Z
# 1       5475397       687  2009-10-27T02:00:07Z
# 2      12486084      3101  2009-10-27T01:47:35Z
# 3        626438       256  2021-02-02T15:00:13Z
# 4       3640584       520  2009-10-29T21:24:41Z
# ...         ...       ...                   ...
# 8939   39374455      6880  2018-09-21T10:00:07Z
# 8940   12831682      1930  2017-04-12T06:00:03Z
# 8941   20180526      3489  2017-07-28T11:00:02Z
# 8942    1839017       674  2017-11-17T00:00:02Z
# 8943    1048899       168  2019-05-03T10:00:10Z
#
# [8944 rows x 8 columns]

# %%
video.head()
# Out:
#       video_id         artist  \
# 0  gH476CxJxfg  Daniel Powter
# 1  BbtcTb_WMsg  Daniel Powter
# 2  vEY_mg2y-rg  Daniel Powter
# 3  oDAqDLmixrw  Daniel Powter
# 4  5E4j_n17cTI  Daniel Powter
#
#                                                title    likes  dislikes  \
# 0  Daniel Powter - Bad Day (Official Music Video)...  1534284     23998
# 1  Daniel Powter - Love You Lately (Official Musi...    20718       397
# 2   Daniel Powter - Free Loop (Official Music Video)    89155      1362
# 3    Save Your Life - Ayaka Hirahara & Daniel Powter     5164        50
# 4            Daniel Powter - Next Plane Home (Video)    13046       320
#
#        views  comments             published
# 0  198275400     51550  2009-10-27T02:01:38Z
# 1    5475397       687  2009-10-27T02:00:07Z
# 2   12486084      3101  2009-10-27T01:47:35Z
# 3     626438       256  2021-02-02T15:00:13Z
# 4    3640584       520  2009-10-29T21:24:41Z

# %%
video['channel_id']=None
for i in range(len(channels)):
    for j in range(len(video)):
        if channels['channel_name'][i] == video['artist'][j]:
            video['channel_id'][j] = channels['channelId'][i]
# Out:
# <ipython-input-147-f72d5d254180>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   video['channel_id'][j] = channels['channelId'][i]

# %%
video.head(50)
# Out:
#        video_id         artist  \
# 0   gH476CxJxfg  Daniel Powter
# 1   BbtcTb_WMsg  Daniel Powter
# 2   vEY_mg2y-rg  Daniel Powter
# 3   oDAqDLmixrw  Daniel Powter
# 4   5E4j_n17cTI  Daniel Powter
# 5   JLkuTQMaHYg  Daniel Powter
# 6   mhnn9TZTE3w  Daniel Powter
# 7   J4dagWIRd48  Daniel Powter
# 8   1CaMX1U9Qvo  Daniel Powter
# 9   E2hpitcq1G8  Daniel Powter
# 10  SvLbyKItEUY      Sean Paul
# 11  GzU8KqOY8YA      Sean Paul
# 12  AQ4TW5Z8eu0      Sean Paul
# 13  dW2MmuA1nI4      Sean Paul
# 14  oPQ3o14ksaM      Sean Paul
# 15  SbUBMklQSVU      Sean Paul
# 16  mlf4bidp2yc      Sean Paul
# 17  tDq3fNew1rU      Sean Paul
# 18       #NAME?      Sean Paul
# 19  bMoNV9oWs2E      Sean Paul
# 20  JSGEcjJPgTo      Sean Paul
# 21  0zZ2bifb338      Sean Paul
# 22  8MmW_GOFS8I      Sean Paul
# 23  uUGFhVWPOFs      Sean Paul
# 24  PukKW3gY4uo      Sean Paul
# 25  rsWmrGuuWuE      Sean Paul
# 26  IO4Zrf2o92Q      Sean Paul
# 27  lyH5Jji6ou4      Sean Paul
# 28  i1o9HMGaWxM      Sean Paul
# 29  A-jQRB-r2Do      Sean Paul
# 30  bzz99f_T8Rk      Sean Paul
# 31  8PQgYpnhDIw      Sean Paul
# 32  IBsd1DiFT8w      Sean Paul
# 33  aOZm0OhevSk      Sean Paul
# 34  xiecZPzJoCQ      Sean Paul
# 35  KYS3K2tmz20      Sean Paul
# 36  jBZMrK9P9oE      Sean Paul
# 37  ujOdIUbJkzg      Sean Paul
# 38  5jI-ojIZXJw      Sean Paul
# 39  zH1Z03rno4Y      Sean Paul
# 40  7gNbZv51B2k      Sean Paul
# 41  PDoX5bu-b2Q      Sean Paul
# 42  PxEs9I_TBlg      Sean Paul
# 43  9jLQS-ZY0aQ      Sean Paul
# 38   15315363      1226  2010-02-01T17:26:08Z  UCkdc7gHpavxpgGalxKbgSHA
# 39   37633591      4815  2013-07-31T15:27:52Z  UCkdc7gHpavxpgGalxKbgSHA
# 40    6423222       811  2009-10-27T02:54:58Z  UCkdc7gHpavxpgGalxKbgSHA
# 41     842123         1  2017-02-09T05:13:44Z  UCkdc7gHpavxpgGalxKbgSHA
# 42    1003631        41  2014-11-06T17:17:13Z  UCkdc7gHpavxpgGalxKbgSHA
# 43    1357064       954  2021-03-29T15:00:08Z  UCkdc7gHpavxpgGalxKbgSHA
# 44     280805       401  2021-04-16T18:00:50Z  UCkdc7gHpavxpgGalxKbgSHA
# 45     785406        48  2017-04-08T09:10:53Z  UCkdc7gHpavxpgGalxKbgSHA
# 46    2037772       641               No date  UCkdc7gHpavxpgGalxKbgSHA
# 47     129028         3  2019-08-05T14:38:18Z  UCkdc7gHpavxpgGalxKbgSHA
# 48     272310         1  2018-07-24T11:00:11Z  UCkdc7gHpavxpgGalxKbgSHA
# 49     659641        42  2015-08-07T23:54:41Z  UCkdc7gHpavxpgGalxKbgSHA

# %%
channel_ids = []
channel_name = []
channel_views = []
channel_subscribers = []
channel_published = []
for i in range(len(channels)):
    channel_ids.append(channels['channelId'][i])
    channel_name.append(channels['channel_name'][i])
    channel_views.append(channels['viewers'][i])
    channel_subscribers.append(channels['subscribers'][i])
    channel_published.append(channels['published'][i])

# %% [markdown]
# ### Inserting Rows into the Channel Table

# %%
sql= '''INSERT INTO channels(channel_id,channel_name,viewers,subscribers,published) VALUES (%s,%s,%s,%s,%s)'''

records = []

for i in range(len(channels)):
    records.append([channel_ids[i],channel_name[i],np.int64(channel_views[i]).item(),np.int64(channel_subscribers[i]).item(),channel_published[i]])

#Pandas stores the integer as numpy.int64 or numpy.int32 which MySQL does not support
#So the values must be converted to base int using the np.int64().item()
conenction = create_db_connection(host,user,password,'music')
execute_list_query(connection,sql,records)
connection.close()
# Out:
# MySQL Database connection successful
# Error: '1062 (23000): Duplicate entry 'UCTbOjJv4X1fk-LdfHnWAK1Q' for key 'channels.PRIMARY''

# %%
video.drop(video.loc[video['video_id']=='#NAME?'].index,inplace=True)

# %%
video.drop_duplicates(subset=['video_id'],inplace=True)

# %%
video.reset_index(inplace=True)

# %%
video_ids = []
video_artist = []
video_title = []
video_likes = []
video_dislikes = []
video_views = []
video_comments = []
video_channel = []
for i in range(len(video)):
    video_ids.append(video['video_id'][i])
    video_artist.append(video['artist'][i])
    video_title.append(video['title'][i])
    video_likes.append(video['likes'][i])
    video_dislikes.append(video['dislikes'][i])
    video_views.append(video['views'][i])
    video_comments.append(video['comments'][i])
    video_channel.append(video['channel_id'][i])

# %%
len(video_ids)
# Out:
# 8805

# %% [markdown]
# ### Inserting Rows Into the Video Table

# %%
sql= '''INSERT INTO videos(video_id,artist,title,likes,dislikes,views,comments,channel_id) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)'''

records = []

for i in range(len(video)):
    records.append([video_ids[i],video_artist[i],video_title[i],np.int64(video_likes[i]).item(),np.int64(video_dislikes[i]).item(),np.int64(video_views[i]).item(),np.int64(video_comments[i]).item(),video_channel[i]])

    
conenction = create_db_connection(host,user,password,'music')
execute_list_query(connection,sql,records)
connection.close()
# Out:
# MySQL Database connection successful
# Query successful
